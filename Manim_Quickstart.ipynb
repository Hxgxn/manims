# %% [markdown]
# <a href="https://colab.research.google.com/github/Hxgxn/manims/blob/main/Manim_Quickstart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt update
# !sudo apt install libcairo2-dev ffmpeg texlive texlive-latex-extra texlive-fonts-extra texlive-latex-recommended texlive-science tipa libpango1.0-dev
# !pip install manim
# !pip install IPython --upgrade
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Ign:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/multiverse amd64 Packages [31.5 kB]
# ...

# %%
from manim import *
# Out:
# Manim Community v0.8.0

# %%
# %%manim SquareToCircle
#
# class SquareToCircle(Scene):
#     def construct(self):
#         circle = Circle()  # create a circle
#         circle.set_fill(PINK, opacity=0.5)  # set color and transparency
#
#         square = Square()  # create a square
#         square.rotate(PI)  # rotate a certain amount
#
#         self.play(Create(square))  # animate the creation of the square
#         self.play(Transform(square, circle))  # interpolate the square into the circle
#         self.play(FadeOut(square))  # fade out animation
# Out:
# [07/23/21 12:46:11] INFO     Animation 0 : Using cached data (hash :    ]8;id=1627044371.9330978-728587;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              450974505_3959912353_3689423530)
# [07/23/21 12:46:15] INFO     Animation 1 : Partial movie file        ]8;id=1627044375.1060982-949405;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/SquareTo
#                              Circle/3968072068_2249555954_3689423530
#                              .mp4'
#                     INFO     Animation 2 : Using cached data (hash :    ]8;id=1627044375.119739-282749;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
# ...

# %%
# %%manim CreatingMobjects
#
# class CreatingMobjects(Scene):
#     def construct(self):
#         circle = Circle()
#         self.add(circle)
#         self.wait(1)
#         self.remove(circle)
#         self.wait(1)
# Out:
# [07/23/21 12:49:06] INFO     Animation 0 : Partial movie file        ]8;id=1627044546.5730484-587024;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/Creating
#                              Mobjects/450974505_686439721_1836509117
#                              .mp4'
# [07/23/21 12:49:08] INFO     Animation 1 : Partial movie file        ]8;id=1627044548.82413-702302;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/Creating
#                              Mobjects/3968072068_3204573912_12575217
#                              75.mp4'
# ...

# %%
# %%manim Shapes
#
# class Shapes(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#         triangle = Triangle()
#
#         circle.shift(LEFT)
#         square.shift(UP)
#         triangle.shift(RIGHT)
#
#         self.add(circle, square, triangle)
#         self.wait(1)
# Out:
# [07/23/21 12:50:43] INFO     Animation 0 : Partial movie file        ]8;id=1627044643.468605-741975;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/Shapes/4
#                              50974505_686439721_3918057972.mp4'
#                     INFO                                             ]8;id=1627044643.5638385-686452;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/videos/co
#                              ntent/1080p60/Shapes.mp4'
#                     INFO     Rendered Shapes                                     ]8;id=1627044643.5715463-337710;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
# ...

# %%
# %%manim MobjectPlacement
#
# class MobjectPlacement(Scene):
#     def construct(self):
#         circle = Circle()
#         square = Square()
#         triangle = Triangle()
#
#         # place the circle two units left from the origin
#         circle.move_to(LEFT * 2)
#         # place the square to the left of the circle
#         square.next_to(circle, LEFT)
#         # align the left border of the triangle to the left border of the circle
#         triangle.align_to(circle, LEFT)
#
#         self.add(circle, square, triangle)
#         self.wait(1)
# Out:
# [07/23/21 12:52:00] INFO     Animation 0 : Using cached data (hash :    ]8;id=1627044720.9578233-541374;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              450974505_686439721_3082746833)
# [07/23/21 12:52:01] INFO                                             ]8;id=1627044721.0547037-477204;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/videos/co
#                              ntent/1080p60/MobjectPlacement.mp4'
#                     INFO     Rendered MobjectPlacement                           ]8;id=1627044721.0634742-192105;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 1 animations
# <video controls autoplay loop style="max-width: 25vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
# ...

# %%
# %%manim MobjectStyling
#
# class MobjectStyling(Scene):
#     def construct(self):
#         circle = Circle().shift(LEFT)
#         square = Square().shift(UP)
#         triangle = Triangle().shift(RIGHT)
#
#         circle.set_stroke(color=GREEN, width=20)
#         square.set_fill(YELLOW, opacity=1.0)
#         triangle.set_fill(PINK, opacity=0.5)
#
#         self.add(circle, square, triangle)
#         self.wait(1)
# Out:
# [07/23/21 12:52:24] INFO     Animation 0 : Partial movie file        ]8;id=1627044744.7303143-715103;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/MobjectS
#                              tyling/450974505_686439721_933645684.mp
#                              4'
#                     INFO                                             ]8;id=1627044744.8281512-774115;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/videos/co
#                              ntent/1080p60/MobjectStyling.mp4'
# ...

# %%
# %%manim MobjectZOrder
#
# class MobjectZOrder(Scene):
#     def construct(self):
#         circle = Circle().shift(LEFT)
#         square = Square().shift(UP)
#         triangle = Triangle().shift(RIGHT)
#
#         circle.set_stroke(color=GREEN, width=20)
#         square.set_fill(YELLOW, opacity=1.0)
#         triangle.set_fill(PINK, opacity=0.5)
#
#         self.add(triangle, square, circle)
#         self.wait(1)
# Out:
# [07/23/21 12:53:16] INFO     Animation 0 : Using cached data (hash :    ]8;id=1627044796.8243773-478890;file:///usr/local/lib/python3.7/dist-packages/manim/renderer/cairo_renderer.py\cairo_renderer.py]8;;\:102
#                              450974505_686439721_3915850039)
#                     INFO                                             ]8;id=1627044796.925219-522173;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/videos/co
#                              ntent/1080p60/MobjectZOrder.mp4'
#                     INFO     Rendered MobjectZOrder                              ]8;id=1627044796.9313796-683275;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 1 animations
# <video controls autoplay loop style="max-width: 25vw;"  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
# ...

# %%
config.background_color = GRAY

# %%
config.frame_height
# Out:
# 10.0

# %%
config.frame_height
# Out:
# 10.0

# %%
# %%manim SomeAnimations
#
# class SomeAnimations(Scene):
#     def construct(self):
#         square = Square()
#         self.add(square)
#         text = MarkupText(f'Hello <span fgcolor="{YELLOW}">World</span>', color=RED).scale(3)
#
#
#         # some animations display mobjects, ...
#         self.play(FadeIn(square))
#
#         # ... some move or rotate mobjects around...
#         self.play(Rotate(square, PI/4))
#
#         # some animations remove mobjects from the screen
#         self.play(FadeOut(square))
#         self.wait(0.5)
#         self.add(text)
#         self.play(FadeIn(text))
#         self.wait(2)
#         self.play(FadeOut(text))
#         self.wait(1)
# Out:
# [07/23/21 13:18:16] INFO     Animation 0 : Partial movie file        ]8;id=1627046296.3656185-945468;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/SomeAnim
#                              ations/1957643999_1045735584_3689423530
#                              .mp4'
# [07/23/21 13:18:20] INFO     Animation 1 : Partial movie file        ]8;id=1627046300.2917407-453725;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:415
#                              written in '/content/media/videos/conte
#                              nt/1080p60/partial_movie_files/SomeAnim
#                              ations/343311538_2034700042_3689423530.
#                              mp4'
# ...

# %%
# %%manim ShowScreenResolution
#
# class ShowScreenResolution(Scene):
#     def construct(self):
#         pixel_height = config["pixel_height"]  #  1080 is default
#         pixel_width = config["pixel_width"]  # 1920 is default
#         frame_width = config["frame_width"]
#         frame_height = config["frame_height"]
#         self.add(Dot())
#         d1 = Line(frame_width * LEFT / 2, frame_width * RIGHT / 2).to_edge(DOWN)
#         self.add(d1)
#         self.add(Text(str(pixel_width)).next_to(d1, UP))
#         d2 = Line(frame_height * UP / 2, frame_height * DOWN / 2).to_edge(LEFT)
#         self.add(d2)
#         self.add(Text(str(pixel_height)).next_to(d2, RIGHT))
# Out:
# [07/23/21 13:02:04] INFO                                             ]8;id=1627045324.1010897-984393;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/ShowScreenResolution_ManimCE_v0.8
#                              .0.png'
#                     INFO     Rendered ShowScreenResolution                       ]8;id=1627045324.106731-885569;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim SingleLineColor
#
# class SingleLineColor(Scene):
#     def construct(self):
#         text = MarkupText(f'all in red <span fgcolor="{YELLOW}">except this</span> Text', color=RED)
#         self.add(text)
# Out:
# [07/23/21 13:05:21] INFO                                             ]8;id=1627045521.8373098-545487;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/SingleLineColor_ManimCE_v0.8.0.pn
#                              g'
#                     INFO     Rendered SingleLineColor                            ]8;id=1627045521.8411474-317212;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim DifferentWeight
#
# class DifferentWeight(Scene):
#     def construct(self):
#         import manimpango
#
#         g = VGroup()
#         weight_list = dict(sorted({weight: manimpango.Weight(weight).value for weight in manimpango.Weight}.items(), key=lambda x: x[1]))
#         for weight in weight_list:
#             g += Text(weight.name, weight=weight.name, font="Open Sans")
#         self.add(g.arrange(DOWN).scale(0.5))
# Out:
# [07/23/21 13:07:35] INFO                                             ]8;id=1627045655.8520496-650898;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/DifferentWeight_ManimCE_v0.8.0.pn
#                              g'
#                     INFO     Rendered DifferentWeight                            ]8;id=1627045655.8572726-421305;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim t2gExample
#
# class t2gExample(Scene):
#     def construct(self):
#         t2gindices = Text(
#             'Hello',
#             t2g={
#                 '[1:-1]': (RED,GREEN),
#             },
#         ).move_to(LEFT)
#         t2gwords = Text(
#             'World',
#             t2g={
#                 'World':(RED,BLUE),
#             },
#         ).next_to(t2gindices, RIGHT)
#         self.add(t2gindices, t2gwords)
# Out:
# [07/23/21 13:09:16] INFO                                             ]8;id=1627045756.4786587-4757;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/t2gExample_ManimCE_v0.8.0.png'
#                     INFO     Rendered t2gExample                                 ]8;id=1627045756.4830658-934720;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim HelloLaTeX
#
# class HelloLaTeX(Scene):
#     def construct(self):
#         tex = Tex(r"\LaTeX").scale(3)
#         self.add(tex)
# Out:
# [07/23/21 13:10:02] INFO     Writing "\LaTeX" to                       ]8;id=1627045802.1766064-627801;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              media/Tex/1367895737f9a7d3.tex
#                     INFO                                             ]8;id=1627045802.7939763-426919;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/HelloLaTeX_ManimCE_v0.8.0.png'
#                     INFO     Rendered HelloLaTeX                                 ]8;id=1627045802.8026385-197892;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim MathTeXDemo
#
# class MathTeXDemo(Scene):
#     def construct(self):
#         rtarrow0 = MathTex(r"\xrightarrow{x^6y^8}").scale(2)
#         rtarrow1 = Tex(r"$\xrightarrow{x^6y^8}$").scale(2)
#
#         self.add(VGroup(rtarrow0, rtarrow1).arrange(DOWN))
# Out:
# [07/23/21 13:10:29] INFO     Writing "\xrightarrow{x^6y^8}" to         ]8;id=1627045829.40538-653240;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              media/Tex/bcc5cc24280a6fbf.tex
#                     INFO     Writing "$\xrightarrow{x^6y^8}$" to       ]8;id=1627045829.79549-965121;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              media/Tex/dd96c7f9055ff8b6.tex
# [07/23/21 13:10:30] INFO                                             ]8;id=1627045830.3903193-959444;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/MathTeXDemo_ManimCE_v0.8.0.png'
# ...

# %%
# %%manim AMSLaTeX
#
# class AMSLaTeX(Scene):
#     def construct(self):
#         tex = Tex(r'$\mathtt{H} \looparrowright$ \LaTeX').scale(3)
#         self.add(tex)
# Out:
# [07/23/21 13:10:52] INFO     Writing "$\mathtt{H} \looparrowright$     ]8;id=1627045852.3334637-894369;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              \LaTeX" to media/Tex/b0e92dfc164d9bbf.tex
#                     INFO                                             ]8;id=1627045852.9224331-58326;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/AMSLaTeX_ManimCE_v0.8.0.png'
#                     INFO     Rendered AMSLaTeX                                   ]8;id=1627045852.9289834-482627;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim IncorrectLaTeXSubstringColoring
#
# class IncorrectLaTeXSubstringColoring(Scene):
#     def construct(self):
#         equation = MathTex(
#             r"e^x = x^0 + x^1 + \frac{1}{2} x^2 + \frac{1}{6} x^3 + \cdots + \frac{1}{n!} x^n + \cdots"
#         )
#         equation.set_color_by_tex("x", YELLOW)
#         self.add(equation)
# Out:
# [07/23/21 13:11:23] INFO     Writing "e^x = x^0 + x^1 + \frac{1}{2}    ]8;id=1627045883.5605817-774528;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              x^2 + \frac{1}{6} x^3 + \cdots +
#                              \frac{1}{n!} x^n + \cdots" to
#                              media/Tex/b27987ed71e91907.tex
# [07/23/21 13:11:24] INFO                                             ]8;id=1627045884.3820832-28397;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/IncorrectLaTeXSubstringColoring_M
#                              animCE_v0.8.0.png'
# ...

# %%
# %%manim CorrectLaTeXSubstringColoring
#
# class CorrectLaTeXSubstringColoring(Scene):
#     def construct(self):
#         equation = MathTex(
#             r"e^x = x^0 + x^1 + \frac{1}{2} x^2 + \frac{1}{6} x^3 + \cdots + \frac{1}{n!} x^n + \cdots",
#             substrings_to_isolate="x"
#         )
#         equation.set_color_by_tex("x", YELLOW)
#         self.add(equation)
# Out:
# [07/23/21 13:11:47] INFO     Writing "e^ x  =  x ^0 +  x ^1 +          ]8;id=1627045907.3988125-39619;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              \frac{1}{2}  x ^2 + \frac{1}{6}  x ^3 +
#                              \cdots + \frac{1}{n!}  x ^n + \cdots" to
#                              media/Tex/932fc349fbab063a.tex
#                     INFO     Writing "e^{\quad}" to                    ]8;id=1627045907.8712084-22540;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              media/Tex/29264b1cafc411a3.tex
# [07/23/21 13:11:48] INFO     Writing "x" to                            ]8;id=1627045908.2217503-883450;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              media/Tex/049324c46070fc62.tex
# ...

# %%
# %%manim LaTeXAlignEnvironment
#
# class LaTeXAlignEnvironment(Scene):
#     def construct(self):
#         tex = MathTex(r'f(x) &= 3 + 2 + 1\\ &= 5 + 1 \\ &= 6').scale(2)
#         self.add(tex)
# Out:
# [07/23/21 13:12:21] INFO     Writing "f(x) &= 3 + 2 + 1\\ &= 5 + 1 \\  ]8;id=1627045941.182871-486435;file:///usr/local/lib/python3.7/dist-packages/manim/utils/tex_file_writing.py\tex_file_writing.py]8;;\:83
#                              &= 6" to media/Tex/8391310de24e8f68.tex
#                     INFO                                             ]8;id=1627045941.826-191851;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/LaTeXAlignEnvironment_ManimCE_v0.
#                              8.0.png'
#                     INFO     Rendered LaTeXAlignEnvironment                      ]8;id=1627045941.8304741-312133;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# %%manim T_labelExample
#
# class T_labelExample(Scene):
#     def construct(self):
#         # defines the axes and linear function
#         axes = Axes(x_range=[-1, 10], y_range=[-1, 10], x_length=9, y_length=6)
#         func = axes.get_graph(lambda x: (1/2)*x, color=BLUE)
#         # creates the T_label
#         t_label = axes.get_T_label(x_val=PI, graph=func, label=Tex('\\LaTeX').scale(1))
#         self.add(axes, func, t_label)
# Out:
# [07/23/21 13:42:21] INFO                                             ]8;id=1627047741.6742215-518935;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene_file_writer.py\scene_file_writer.py]8;;\:597
#                              File ready at '/content/media/images/co
#                              ntent/T_labelExample_ManimCE_v0.8.0.png
#                              '
#                     INFO     Rendered T_labelExample                             ]8;id=1627047741.6813903-526630;file:///usr/local/lib/python3.7/dist-packages/manim/scene/scene.py\scene.py]8;;\:229
#                              Played 0 animations

# %%
# !sudo apt install texlive-extra-utils
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   ghostscript gsfonts libfile-homedir-perl libfile-which-perl
#   libmime-charset-perl libsombok3 libunicode-linebreak-perl libyaml-tiny-perl
# Suggested packages:
#   ghostscript-x libencode-hanextra-perl libpod2-base-perl chktex dvidvi dvipng
#   fragmaster lacheck latexdiff latexmk purifyeps xindy
# The following NEW packages will be installed:
#   ghostscript gsfonts libfile-homedir-perl libfile-which-perl
#   libmime-charset-perl libsombok3 libunicode-linebreak-perl libyaml-tiny-perl
#   texlive-extra-utils
# 0 upgraded, 9 newly installed, 0 to remove and 80 not upgraded.
# Need to get 24.3 MB of archives.
# After this operation, 31.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 ghostscript amd64 9.26~dfsg+0-0ubuntu0.18.04.14 [51.3 kB]
# ...
